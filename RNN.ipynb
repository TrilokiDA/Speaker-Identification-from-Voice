# %%
#extracting data from csv files into numpy arrays
from numpy import genfromtxt
import numpy as np
x_train = genfromtxt('train_data1.csv', delimiter=',')
y_train = genfromtxt('train_labels1.csv', delimiter=',')
x_test = genfromtxt('test_data1.csv', delimiter=',')
y_test = genfromtxt('test_labels1.csv', delimiter=',')

# %%
#shape
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((480, 200), (121, 200), (480,), (121,))

# %%
#converting to one hot
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)
y_train.shape,y_test.shape
# Out:
# Using TensorFlow backend.
# ((480, 7), (121, 7))

# %%
#reshaping to 2D 
x_train=np.reshape(x_train,(x_train.shape[0], 40,5))
x_test=np.reshape(x_test,(x_test.shape[0], 40,5))
x_train.shape,x_test.shape
# Out:
# ((480, 40, 5), (121, 40, 5))

# %%
#reshaping to shape required by RNN
x_train=np.reshape(x_train,(x_train.shape[0], 40,5))
x_test=np.reshape(x_test,(x_test.shape[0], 40,5))

# %%
#shapes
x_train.shape,x_test.shape
# Out:
# ((480, 40, 5), (121, 40, 5))

# %%
from keras import Sequential
from keras import optimizers
from keras.layers import Dense,Dropout,Activation,SimpleRNN,GRU
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
#adding layers and forming the model
model = Sequential()
model.add(SimpleRNN(256, activation="relu", input_shape=(40,5), return_sequences=True))
model.add(Dropout(0.15))

model.add(SimpleRNN(128, activation="relu"))
model.add(Dropout(0.15))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.15))
model.add(Dense(units=7,activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
from keras.utils import plot_model
plot_model(model, to_file='RNNmodel.png')

# %%
#compiling
model.compile(optimizer=optimizers.Adam(lr=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#fitting
history = model.fit(x_train,y_train,epochs=21,validation_data=(x_test,y_test),batch_size=40)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 480 samples, validate on 121 samples
# Epoch 1/21
# 480/480 [==============================] - 1s 3ms/step - loss: 1.8611 - acc: 0.2646 - val_loss: 1.7712 - val_acc: 0.2893
# Epoch 2/21
# 480/480 [==============================] - 1s 2ms/step - loss: 1.6667 - acc: 0.3458 - val_loss: 1.6131 - val_acc: 0.3223
# Epoch 3/21
# 480/480 [==============================] - 1s 2ms/step - loss: 1.3693 - acc: 0.5083 - val_loss: 1.1450 - val_acc: 0.5289
# Epoch 4/21
# 480/480 [==============================] - 1s 2ms/step - loss: 1.1023 - acc: 0.5667 - val_loss: 1.1862 - val_acc: 0.5537
# Epoch 5/21
# 480/480 [==============================] - 1s 2ms/step - loss: 1.0690 - acc: 0.5729 - val_loss: 0.9375 - val_acc: 0.6198
# Epoch 6/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.8248 - acc: 0.6354 - val_loss: 0.6362 - val_acc: 0.7851
# Epoch 7/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.7491 - acc: 0.7000 - val_loss: 0.8620 - val_acc: 0.7025
# Epoch 8/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.6975 - acc: 0.7333 - val_loss: 0.6385 - val_acc: 0.6446
# Epoch 9/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.5839 - acc: 0.7521 - val_loss: 0.4057 - val_acc: 0.8430
# Epoch 10/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.4100 - acc: 0.8167 - val_loss: 0.3393 - val_acc: 0.8347
# Epoch 11/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.2607 - acc: 0.8792 - val_loss: 0.1962 - val_acc: 0.9174
# Epoch 12/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.2387 - acc: 0.9229 - val_loss: 0.2345 - val_acc: 0.9256
# Epoch 13/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.2377 - acc: 0.9083 - val_loss: 0.1316 - val_acc: 0.9669
# Epoch 14/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.1511 - acc: 0.9583 - val_loss: 0.1359 - val_acc: 0.9669
# Epoch 15/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.4555 - acc: 0.8667 - val_loss: 0.4626 - val_acc: 0.8926
# Epoch 16/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3794 - acc: 0.8896 - val_loss: 0.1499 - val_acc: 0.9339
# Epoch 17/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.1772 - acc: 0.9437 - val_loss: 0.1023 - val_acc: 0.9669
# Epoch 18/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.0716 - acc: 0.9729 - val_loss: 0.1606 - val_acc: 0.9421
# Epoch 19/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.0790 - acc: 0.9771 - val_loss: 0.0976 - val_acc: 0.9669
# Epoch 20/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.0762 - acc: 0.9792 - val_loss: 0.0273 - val_acc: 0.9835
# Epoch 21/21
# 480/480 [==============================] - 1s 2ms/step - loss: 0.1229 - acc: 0.9604 - val_loss: 0.0358 - val_acc: 0.9835

# %%
#Saving the model
import h5py
model.save('RNNmodel.h5')

# %%
import matplotlib.pyplot as plt


# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#train and test loss and scores respectively
train_loss_score=model.evaluate(x_train,y_train)
test_loss_score=model.evaluate(x_test,y_test)
print(train_loss_score)
print(test_loss_score)
# Out:
# 480/480 [==============================] - 0s 673us/step
# 121/121 [==============================] - 0s 622us/step
# [0.02840589452534914, 0.99375]
# [0.03578794926158653, 0.9834710743801653]

# %%
x_test[43]
# Out:
# array([[-3.00005246e+02,  1.34180401e+02,  1.13283157e+00,
#          2.35453734e+01,  2.53087379e+00],
#        [-1.18000143e+01, -1.68606152e+01,  4.51555539e+00,
#         -8.71673941e+00, -3.49115335e+00],
#        [-1.72629066e+01, -9.00145651e+00,  2.51001807e+00,
#         -4.09627364e+00,  1.10666725e+00],
#        [-8.00987494e+00, -8.90823292e+00,  1.74716911e+00,
#          4.66700799e+00, -6.07632487e+00],
#        [ 1.74446460e+00,  7.71220662e+00, -5.61526659e+00,
#         -2.13610799e+00, -2.75287043e+00],
#        [-6.39348283e+00, -6.35213149e+00, -6.22639934e+00,
#         -8.12519101e+00, -5.24943934e+00],
#        [-4.64009263e+00, -6.81697629e+00, -4.33620680e+00,
#          3.78268457e-01, -6.83232483e-01],
#        [-1.41521550e+00,  5.87669867e+00,  5.83503650e+00,
#        [ 3.56258704e-03,  4.43458321e-03,  7.73732995e-02,
#          9.17667379e-03,  1.79041413e-02],
#        [ 1.73358906e-01,  8.97125108e-02,  1.11766672e-01,
#          8.08862941e-02,  6.84290741e-02],
#        [ 5.09150186e-02,  4.46222203e-02,  5.38460164e-02,
#          7.56538369e-02,  1.41255212e-01],
#        [ 2.23914687e-01,  3.14334992e-01,  2.58797273e-01,
#          2.20143787e-01,  1.56158263e-01],
#        [ 1.21056327e-01,  9.23601991e-02,  5.36557822e-02,
#          3.48017061e-02,  3.75690187e-02],
#        [ 1.57222317e-01,  4.87592029e-02,  2.63077934e-02,
#          0.00000000e+00,  1.78467456e-02],
#        [ 2.87497002e-02,  3.62075411e-02,  2.53429429e-02,
#          2.14997574e-02,  3.68169941e-03],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          3.52867284e-03,  2.10535649e-02]])

# %%
y_test[43]
# Out:
# array([0., 0., 0., 0., 0., 1., 0.], dtype=float32)

# %%
from keras.models import load_model
model1 = load_model("RNNmodel.h5")
model1.predict(np.array([[[-2.73306311e+02,  1.58642348e+02, -2.51804661e+01,
         2.86019095e+01,  6.99706422e+00],
       [-1.42294665e+01, -2.34645073e+01, -6.28480623e+00,
        -8.65793279e+00, -4.55593675e+00],
       [-6.92275717e+00,  5.60497474e+00,  3.16393417e+00,
        -1.47657957e+01,  1.51526806e+01],
       [-3.17696095e+00, -1.23760858e+01,  3.91984523e+00,
        -4.87903315e+00, -4.95804955e+00],
       [-4.49944483e+00, -1.37032968e+00, -3.22835255e+00,
        -4.88906624e+00, -3.42968136e+00],
       [-6.82397100e+00, -2.99805555e+00, -6.23055454e-01,
        -6.58288230e+00, -2.35257537e+00],
       [-9.68074613e-01, -4.47761105e+00, -2.84575784e+00,
        -3.32549884e+00, -1.56158142e+00],
       [-2.29576016e+00,  1.29711570e+00,  4.93674808e+00,
         6.87433310e+00,  7.94018623e+00],
       [ 4.93491897e-01,  6.94870545e+00,  4.72268216e+00,
         1.18707843e+01,  2.44250603e+01],
       [ 2.88819540e+01,  4.10303611e+01,  1.16491604e+01,
         1.10405546e+01,  2.44277799e+00],
       [ 4.24940737e-01,  5.28936982e-01,  2.60800369e-01,
         3.48806603e-01,  2.33123275e-01],
       [ 2.98151289e-01,  3.37060296e-01,  3.26388803e-01,
         2.14382093e-01,  2.34875481e-01],
       [ 3.28661707e-01,  2.62339352e-01,  1.66294454e-01,
         3.66376503e-01,  3.56937573e-01],
       [ 2.58143551e-01,  5.20451234e-02,  1.15097583e-02,
         5.69027397e-03,  1.80453274e-02],
       [ 2.85969803e-02,  6.79184780e-03,  3.17920136e-03,
         8.93570531e-04,  2.61840371e-04],
       [ 2.62720411e-04,  8.96713784e-04,  5.93085915e-04,
         2.74660863e-04,  8.97915254e-05],
       [ 2.12655137e-01,  1.97313694e-01,  1.75298747e-01,
